# %%
# Umgebung automatisch einrichten
# Lädt IPython-Erweiterung für automatisches Nachladen von Modulen
# %load_ext autoreload
# Aktiviert automatisches Reloading für alle importierten Module bei jeder Zellausführung
# %autoreload 2
# %run ../config/preamble.py

from src import provider

## Initalizing the connection to the DB
provider.init()

# %% [markdown]
# # 🧪 Experiment: Oxford

# %% [markdown]
# # HEATMAP

# %%
from viz.widgets import show_heatmap_widget
heatmap_state = {}
show_heatmap_widget(heatmap_state=heatmap_state)

# %%
from viz.widgets import show_plate_slot_selection_widget
# Default to plate from heatmap if available
default_plate = heatmap_state.get("platte", None)
show_plate_slot_selection_widget(default_plate=default_plate)

# %%
from src.data_processing import filter_constant_HF_signals
df = filter_constant_HF_signals(selected_df)

# %%
df = df[~df['Signal'].isin(['ToolOrientation', 'WCSPosition'])]

# %% [markdown]
# # External Sensor Values

# %%
df_oscilloscope = provider.df(22,1,  data_origin="Oscilloscope",)

# %%
df_oscilloscope = df_oscilloscope[~df_oscilloscope['Signal'].isin(['ToolOrientation', 'WCSPosition'])]

# %%
from viz.visualizer import create_axiswise_plots2
figs = create_axiswise_plots2(df_oscilloscope, color_column='Signal', add_vlines = True, normalize_method='minmax', x_column='WCS_Y_mm', color_palette=None, max_display_points=20000)
for key, fig in figs.items():
    fig.show()

# %% [markdown]
# # HF Data Figures

# %%
df_hf = provider.df(22,1, data_origin="HF_Data")

# %%
from src.data_processing import filter_constant_HF_signals
df_hf = filter_constant_HF_signals(df_hf)

# %%
df_hf = df_hf[~df_hf['Signal'].isin(['ToolOrientation', 'WCSPosition'])]

# %%
from viz.visualizer import create_axiswise_plots2
figs = create_axiswise_plots2(df_hf, color_column='Signal', add_vlines = True, normalize_method='minmax', x_column='WCS_Y_mm', color_palette=None, max_display_points=20000)
for key, fig in figs.items():
    fig.show()

# %% [markdown]
# # LF Data Figures

# %%
df_lf = provider.df(22,1, data_origin="LF_Data")

# %%
df_lf = df_lf[~df_lf['Signal'].isin(['ToolOrientation', 'WCSPosition'])]

# %%
from viz.visualizer import create_axiswise_plots2
figs = create_axiswise_plots2(df_lf, color_column='Signal', signal_color_mapping = False, marker = True, add_vlines = True, normalize_method=None, x_column='WCS_Y_mm', max_display_points=20000)
for key, fig in figs.items():
    fig.show()

# %%
from viz.widgets import show_plate_slot_filter_widget
show_plate_slot_filter_widget()
